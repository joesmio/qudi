# %%
confocalgui.refocus_clicked()

# %%
import time
import matplotlib.pyplot as plt
#mywaterloobox._count_frequency = 50
mywaterloobox.set_up_clock(clock_frequency=50)
mywaterloobox.set_up_counter()
value = []
for i in range(0,180):
    angle = 2*i
    rotmot.move_abs({'phi':angle})
    time.sleep(0.1)
    value.append( np.mean(mywaterloobox.get_counter(samples = 10)))
mywaterloobox.close_counter()
mywaterloobox.close_clock()
plt.plot(value)
plt.show()

# %%
np.mean(1)
# Out:
# 1.0

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(1)

# %%
plt.plot(value)
plt.savefig('not_optimised.pdf')

# %%
plt.plot(value)
plt.show()
